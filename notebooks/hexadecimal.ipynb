# %% [markdown]
# # Introduction
#
# This notebook will guide you through a series of exercises exploring **hexadecimal number systems** — one of the most important topics in computer science.
# Hexadecimal (base 16) is a compact way to represent binary data and is widely used in **memory addressing**, **colour codes**, and **machine-level programming**.
#
# You will begin by examining how to convert numbers between **denary (base 10)** and **hexadecimal (base 16)**, using the **division–remainder method**.
# You’ll then build and test functions that perform these conversions in Python.
#
# ---
#
# ## What You Will Learn
#
# - Understand how hexadecimal digits represent values 0–15.
# - Debug and complete real Python functions that perform conversions.
# - Apply algorithmic thinking to solve problems methodically.
# - Test your code using provided unit tests to check for correctness and robustness.
#
# ---
#
# ## Learning Outcomes
#
# By the end of this activity, you should be able to:
#
# - Convert denary numbers to hexadecimal and back again confidently.
# - Explain how division and remainder operations underpin number base conversions.
# - Write your own reliable conversion functions from scratch.
#
# ---
#
# ## Extension
#
# The notebook also includes **extension challenges**, such as creating a **hex-to-binary converter**, for those who wish to explore further applications of base systems in computing.

# %% [markdown]
# ## **Task 1:** Hexadecimal digit converter
#
# In this section you will correct the function below.  It currently only works for the values 1 and 2.
#
# - **Easy**: Extend the code to work for all the hex values
# - **Medium**: Write python code to test whether it is in the range 0-9 and if so just return the integer.
# - **🧠 Stretch**: Use the ord function to if it is a number or a letter and if this is in range.
# - **🦾 Extension**: Write validation to return an error when the function is out of range.

# %%
def convert_hex_digit(digit: str) -> int:
    if digit == "1":
        return 1
    elif digit == "2":
        return 2

# %% [markdown]
# ### 🔍 **Testing**: Use the box below to test if you code works

# %%
# tests
for character in "0123456789ABCDEF":
    try:
        print(convert_hex_digit(character))
    except ValueError as e:
        print(e)
# Out:
# None
# 1
# 2
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# ## **Task 2**: Hexadecimal Number Convertor
#
# Correct and improve the following code. The program is meant to input a two digit hexadecimal string and return its value.  There is a logic error in the code.
#
# 1. Fix the logic and syntax errors
# 2. Make this work for 3 digits
# 3. Make this work for any number of digits
# 4. Add error handling for if there are values input that are not hexadecimal digits.

# %%
def convert_hex_to_denary(hex_string: str) -> int:
    '''This function inputs a hex string and returns the denary value as an integer '''
    column_1_value == convert_hex_digit(hex_string[0])
    column_2_value = convert_hex_digit(hex_string[1]

    return column_1_value * 15 + column_1_value
# Out:
#   Cell In[15], line 4
#     column_2_value = convert_hex_digit(hex_string[1]
#                                       ^
# SyntaxError: '(' was never closed

# %% [markdown]
# ### 🔍 **Testing**: Use the box below to test if you code works

# %%
print(convert_hex_to_denary("22"))

# %% [markdown]
# ## 🧠 **Stretch Task**: Denary to Hex Convertor
#
# Use the integer division operator **//** and the remainder (aka modulus operator) **%** to repeated divide a number by 16 and append the remainder to a string. This will convert from denary to binary

# %%
def convert_denary_to_hex(number: int) -> str:
    return True

# %% [markdown]
# ## **🦾Extension Task**: Write a hex to binary converter
#
# Every hex digit has a 4 bit binary value.  These can be appeneded together to convert the number.  Write 2 functions:
# 1. convert_hex_digit_to_binary - this converts a single hex digit to a nibble of binary
# 2. convert_hex_to_binary - this converts a hex string of many characters into binary.

# %%
def convert_hex_digit_to_binary(digit:str) -> str:
    return "0000"

def convert_hex_to_binary(hex: str) -> str:
    return "00000000"

print(convert_hex_digit_to_binary("FF"))
